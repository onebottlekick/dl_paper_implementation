# %%
from experiment_utils import *
from model import ViT
from configs import b16_config
from torchvision.datasets import CIFAR10
from torchvision import transforms

# %%
config = b16_config()
config.update({'num_classes':10})
model = load_model(ViT, 'pretrained/cifar10_224.pth', config)

# %%
import torch
from thop import profile

macs, params = profile(model, inputs=(torch.randn(1, 3, 224, 224),))
print('MACs:', f'{macs/1e9:.2f} G')
print('Params', f'{params/1e6:.2f} M')
# Out:
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# MACs: 16.86 G
# Params 85.65 M

# %%
dataset = CIFAR10(root='../datasets', train=False, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]))

data = dataset.data
label = dataset.targets
# Out:
# Files already downloaded and verified

# %%
model_summary(model, 3, 224, 'cpu')
# Out:
# =============================================================================================================
#                                                    Kernel Shape  \
# Layer
# 0_to_patch                                                    -
# 1_linear_projection                                  [768, 768]
# 2_transformer_encoder.blocks.0.LayerNorm_layer_...        [768]
# 3_transformer_encoder.blocks.0.msa.Linear_fc_q       [768, 768]
# 4_transformer_encoder.blocks.0.msa.Linear_fc_k       [768, 768]
# 5_transformer_encoder.blocks.0.msa.Linear_fc_v       [768, 768]
# 6_transformer_encoder.blocks.0.msa.Dropout_dropout            -
# 7_transformer_encoder.blocks.0.msa.Linear_fc_o       [768, 768]
# 8_transformer_encoder.blocks.0.Dropout_dropout                -
# 9_transformer_encoder.blocks.0.LayerNorm_layer_...        [768]
# 10_transformer_encoder.blocks.0.mlp.Linear_fc1      [768, 3072]
# 11_transformer_encoder.blocks.0.mlp.GELU_activa...            -
# 12_transformer_encoder.blocks.0.mlp.Dropout_dro...            -
# 13_transformer_encoder.blocks.0.mlp.Linear_fc2      [3072, 768]
# 14_transformer_encoder.blocks.0.mlp.Dropout_dro...            -
# 15_transformer_encoder.blocks.0.Dropout_dropout               -
# 16_transformer_encoder.blocks.1.LayerNorm_layer...        [768]
# 17_transformer_encoder.blocks.1.msa.Linear_fc_q      [768, 768]
# 18_transformer_encoder.blocks.1.msa.Linear_fc_k      [768, 768]
# 19_transformer_encoder.blocks.1.msa.Linear_fc_v      [768, 768]
# 20_transformer_encoder.blocks.1.msa.Dropout_dro...            -
# 21_transformer_encoder.blocks.1.msa.Linear_fc_o      [768, 768]
# 22_transformer_encoder.blocks.1.Dropout_dropout               -
# 23_transformer_encoder.blocks.1.LayerNorm_layer...        [768]
# 24_transformer_encoder.blocks.1.mlp.Linear_fc1      [768, 3072]
# 25_transformer_encoder.blocks.1.mlp.GELU_activa...            -
# 26_transformer_encoder.blocks.1.mlp.Dropout_dro...            -
# 27_transformer_encoder.blocks.1.mlp.Linear_fc2      [3072, 768]
# 28_transformer_encoder.blocks.1.mlp.Dropout_dro...            -
# 29_transformer_encoder.blocks.1.Dropout_dropout               -
# 30_transformer_encoder.blocks.2.LayerNorm_layer...        [768]
# 31_transformer_encoder.blocks.2.msa.Linear_fc_q      [768, 768]
# 32_transformer_encoder.blocks.2.msa.Linear_fc_k      [768, 768]
# 33_transformer_encoder.blocks.2.msa.Linear_fc_v      [768, 768]
# 34_transformer_encoder.blocks.2.msa.Dropout_dro...            -
# 35_transformer_encoder.blocks.2.msa.Linear_fc_o      [768, 768]
# 36_transformer_encoder.blocks.2.Dropout_dropout               -
# 37_transformer_encoder.blocks.2.LayerNorm_layer...        [768]
# 38_transformer_encoder.blocks.2.mlp.Linear_fc1      [768, 3072]
# 39_transformer_encoder.blocks.2.mlp.GELU_activa...            -
# 40_transformer_encoder.blocks.2.mlp.Dropout_dro...            -
# 41_transformer_encoder.blocks.2.mlp.Linear_fc2      [3072, 768]
# 42_transformer_encoder.blocks.2.mlp.Dropout_dro...            -
# 43_transformer_encoder.blocks.2.Dropout_dropout               -
# 44_transformer_encoder.blocks.3.LayerNorm_layer...        [768]
# 45_transformer_encoder.blocks.3.msa.Linear_fc_q      [768, 768]
# 46_transformer_encoder.blocks.3.msa.Linear_fc_k      [768, 768]
# 47_transformer_encoder.blocks.3.msa.Linear_fc_v      [768, 768]
# 48_transformer_encoder.blocks.3.msa.Dropout_dro...            -
# 49_transformer_encoder.blocks.3.msa.Linear_fc_o      [768, 768]
# 50_transformer_encoder.blocks.3.Dropout_dropout               -
# 51_transformer_encoder.blocks.3.LayerNorm_layer...        [768]
# 52_transformer_encoder.blocks.3.mlp.Linear_fc1      [768, 3072]
# 53_transformer_encoder.blocks.3.mlp.GELU_activa...            -
# 54_transformer_encoder.blocks.3.mlp.Dropout_dro...            -
# 55_transformer_encoder.blocks.3.mlp.Linear_fc2      [3072, 768]
# 56_transformer_encoder.blocks.3.mlp.Dropout_dro...            -
# 57_transformer_encoder.blocks.3.Dropout_dropout               -
# 58_transformer_encoder.blocks.4.LayerNorm_layer...        [768]
# 59_transformer_encoder.blocks.4.msa.Linear_fc_q      [768, 768]
# 60_transformer_encoder.blocks.4.msa.Linear_fc_k      [768, 768]
# 61_transformer_encoder.blocks.4.msa.Linear_fc_v      [768, 768]
# 62_transformer_encoder.blocks.4.msa.Dropout_dro...            -
# 63_transformer_encoder.blocks.4.msa.Linear_fc_o      [768, 768]
# 64_transformer_encoder.blocks.4.Dropout_dropout               -
# 65_transformer_encoder.blocks.4.LayerNorm_layer...        [768]
# 66_transformer_encoder.blocks.4.mlp.Linear_fc1      [768, 3072]
# 67_transformer_encoder.blocks.4.mlp.GELU_activa...            -
# 68_transformer_encoder.blocks.4.mlp.Dropout_dro...            -
# 69_transformer_encoder.blocks.4.mlp.Linear_fc2      [3072, 768]
# 70_transformer_encoder.blocks.4.mlp.Dropout_dro...            -
# 71_transformer_encoder.blocks.4.Dropout_dropout               -
# 72_transformer_encoder.blocks.5.LayerNorm_layer...        [768]
# 73_transformer_encoder.blocks.5.msa.Linear_fc_q      [768, 768]
# 74_transformer_encoder.blocks.5.msa.Linear_fc_k      [768, 768]
# 75_transformer_encoder.blocks.5.msa.Linear_fc_v      [768, 768]
# 76_transformer_encoder.blocks.5.msa.Dropout_dro...            -
# 77_transformer_encoder.blocks.5.msa.Linear_fc_o      [768, 768]
# 78_transformer_encoder.blocks.5.Dropout_dropout               -
# 79_transformer_encoder.blocks.5.LayerNorm_layer...        [768]
# 80_transformer_encoder.blocks.5.mlp.Linear_fc1      [768, 3072]
# 81_transformer_encoder.blocks.5.mlp.GELU_activa...            -
# 82_transformer_encoder.blocks.5.mlp.Dropout_dro...            -
# 83_transformer_encoder.blocks.5.mlp.Linear_fc2      [3072, 768]
# 84_transformer_encoder.blocks.5.mlp.Dropout_dro...            -
# 85_transformer_encoder.blocks.5.Dropout_dropout               -
# 86_transformer_encoder.blocks.6.LayerNorm_layer...        [768]
# 87_transformer_encoder.blocks.6.msa.Linear_fc_q      [768, 768]
# 88_transformer_encoder.blocks.6.msa.Linear_fc_k      [768, 768]
# 89_transformer_encoder.blocks.6.msa.Linear_fc_v      [768, 768]
# 90_transformer_encoder.blocks.6.msa.Dropout_dro...            -
# 91_transformer_encoder.blocks.6.msa.Linear_fc_o      [768, 768]
# 92_transformer_encoder.blocks.6.Dropout_dropout               -
# 93_transformer_encoder.blocks.6.LayerNorm_layer...        [768]
# 94_transformer_encoder.blocks.6.mlp.Linear_fc1      [768, 3072]
# 95_transformer_encoder.blocks.6.mlp.GELU_activa...            -
# 96_transformer_encoder.blocks.6.mlp.Dropout_dro...            -
# 97_transformer_encoder.blocks.6.mlp.Linear_fc2      [3072, 768]
# 98_transformer_encoder.blocks.6.mlp.Dropout_dro...            -
# 99_transformer_encoder.blocks.6.Dropout_dropout               -
# 100_transformer_encoder.blocks.7.LayerNorm_laye...        [768]
# 101_transformer_encoder.blocks.7.msa.Linear_fc_q     [768, 768]
# 102_transformer_encoder.blocks.7.msa.Linear_fc_k     [768, 768]
# 103_transformer_encoder.blocks.7.msa.Linear_fc_v     [768, 768]
# 104_transformer_encoder.blocks.7.msa.Dropout_dr...            -
# 105_transformer_encoder.blocks.7.msa.Linear_fc_o     [768, 768]
# 106_transformer_encoder.blocks.7.Dropout_dropout              -
# 107_transformer_encoder.blocks.7.LayerNorm_laye...        [768]
# 108_transformer_encoder.blocks.7.mlp.Linear_fc1     [768, 3072]
# 109_transformer_encoder.blocks.7.mlp.GELU_activ...            -
# 110_transformer_encoder.blocks.7.mlp.Dropout_dr...            -
# 111_transformer_encoder.blocks.7.mlp.Linear_fc2     [3072, 768]
# 112_transformer_encoder.blocks.7.mlp.Dropout_dr...            -
# 113_transformer_encoder.blocks.7.Dropout_dropout              -
# 114_transformer_encoder.blocks.8.LayerNorm_laye...        [768]
# 115_transformer_encoder.blocks.8.msa.Linear_fc_q     [768, 768]
# 116_transformer_encoder.blocks.8.msa.Linear_fc_k     [768, 768]
# 117_transformer_encoder.blocks.8.msa.Linear_fc_v     [768, 768]
# 118_transformer_encoder.blocks.8.msa.Dropout_dr...            -
# 119_transformer_encoder.blocks.8.msa.Linear_fc_o     [768, 768]
# 120_transformer_encoder.blocks.8.Dropout_dropout              -
# 121_transformer_encoder.blocks.8.LayerNorm_laye...        [768]
# 122_transformer_encoder.blocks.8.mlp.Linear_fc1     [768, 3072]
# 123_transformer_encoder.blocks.8.mlp.GELU_activ...            -
# 124_transformer_encoder.blocks.8.mlp.Dropout_dr...            -
# 125_transformer_encoder.blocks.8.mlp.Linear_fc2     [3072, 768]
# 126_transformer_encoder.blocks.8.mlp.Dropout_dr...            -
# 127_transformer_encoder.blocks.8.Dropout_dropout              -
# 128_transformer_encoder.blocks.9.LayerNorm_laye...        [768]
# 129_transformer_encoder.blocks.9.msa.Linear_fc_q     [768, 768]
# 130_transformer_encoder.blocks.9.msa.Linear_fc_k     [768, 768]
# 131_transformer_encoder.blocks.9.msa.Linear_fc_v     [768, 768]
# 132_transformer_encoder.blocks.9.msa.Dropout_dr...            -
# 133_transformer_encoder.blocks.9.msa.Linear_fc_o     [768, 768]
# 134_transformer_encoder.blocks.9.Dropout_dropout              -
# 135_transformer_encoder.blocks.9.LayerNorm_laye...        [768]
# 136_transformer_encoder.blocks.9.mlp.Linear_fc1     [768, 3072]
# 137_transformer_encoder.blocks.9.mlp.GELU_activ...            -
# 138_transformer_encoder.blocks.9.mlp.Dropout_dr...            -
# 139_transformer_encoder.blocks.9.mlp.Linear_fc2     [3072, 768]
# 140_transformer_encoder.blocks.9.mlp.Dropout_dr...            -
# 141_transformer_encoder.blocks.9.Dropout_dropout              -
# 142_transformer_encoder.blocks.10.LayerNorm_lay...        [768]
# 143_transformer_encoder.blocks.10.msa.Linear_fc_q    [768, 768]
# 144_transformer_encoder.blocks.10.msa.Linear_fc_k    [768, 768]
# 145_transformer_encoder.blocks.10.msa.Linear_fc_v    [768, 768]
# 146_transformer_encoder.blocks.10.msa.Dropout_d...            -
# 147_transformer_encoder.blocks.10.msa.Linear_fc_o    [768, 768]
# 148_transformer_encoder.blocks.10.Dropout_dropout             -
# 149_transformer_encoder.blocks.10.LayerNorm_lay...        [768]
# 150_transformer_encoder.blocks.10.mlp.Linear_fc1    [768, 3072]
# 151_transformer_encoder.blocks.10.mlp.GELU_acti...            -
# 152_transformer_encoder.blocks.10.mlp.Dropout_d...            -
# 153_transformer_encoder.blocks.10.mlp.Linear_fc2    [3072, 768]
# 154_transformer_encoder.blocks.10.mlp.Dropout_d...            -
# 155_transformer_encoder.blocks.10.Dropout_dropout             -
# 156_transformer_encoder.blocks.11.LayerNorm_lay...        [768]
# 157_transformer_encoder.blocks.11.msa.Linear_fc_q    [768, 768]
# 158_transformer_encoder.blocks.11.msa.Linear_fc_k    [768, 768]
# 159_transformer_encoder.blocks.11.msa.Linear_fc_v    [768, 768]
# 160_transformer_encoder.blocks.11.msa.Dropout_d...            -
# 161_transformer_encoder.blocks.11.msa.Linear_fc_o    [768, 768]
# 162_transformer_encoder.blocks.11.Dropout_dropout             -
# 163_transformer_encoder.blocks.11.LayerNorm_lay...        [768]
# 164_transformer_encoder.blocks.11.mlp.Linear_fc1    [768, 3072]
# 165_transformer_encoder.blocks.11.mlp.GELU_acti...            -
# 166_transformer_encoder.blocks.11.mlp.Dropout_d...            -
# 167_transformer_encoder.blocks.11.mlp.Linear_fc2    [3072, 768]
# 168_transformer_encoder.blocks.11.mlp.Dropout_d...            -
# 169_transformer_encoder.blocks.11.Dropout_dropout             -
# 170_mlp_head                                          [768, 10]
#
#                                                          Output Shape  \
# Layer
# 0_to_patch                                              [1, 768, 196]
# 1_linear_projection                                     [1, 196, 768]
# 2_transformer_encoder.blocks.0.LayerNorm_layer_...      [1, 197, 768]
# 3_transformer_encoder.blocks.0.msa.Linear_fc_q          [1, 197, 768]
# 4_transformer_encoder.blocks.0.msa.Linear_fc_k          [1, 197, 768]
# 5_transformer_encoder.blocks.0.msa.Linear_fc_v          [1, 197, 768]
# 6_transformer_encoder.blocks.0.msa.Dropout_dropout  [1, 12, 197, 197]
# 7_transformer_encoder.blocks.0.msa.Linear_fc_o          [1, 197, 768]
# 8_transformer_encoder.blocks.0.Dropout_dropout          [1, 197, 768]
# 9_transformer_encoder.blocks.0.LayerNorm_layer_...      [1, 197, 768]
# 10_transformer_encoder.blocks.0.mlp.Linear_fc1         [1, 197, 3072]
# 11_transformer_encoder.blocks.0.mlp.GELU_activa...     [1, 197, 3072]
# 12_transformer_encoder.blocks.0.mlp.Dropout_dro...     [1, 197, 3072]
# 13_transformer_encoder.blocks.0.mlp.Linear_fc2          [1, 197, 768]
# 14_transformer_encoder.blocks.0.mlp.Dropout_dro...      [1, 197, 768]
# 15_transformer_encoder.blocks.0.Dropout_dropout         [1, 197, 768]
# 16_transformer_encoder.blocks.1.LayerNorm_layer...      [1, 197, 768]
# 17_transformer_encoder.blocks.1.msa.Linear_fc_q         [1, 197, 768]
# 18_transformer_encoder.blocks.1.msa.Linear_fc_k         [1, 197, 768]
# 19_transformer_encoder.blocks.1.msa.Linear_fc_v         [1, 197, 768]
# 20_transformer_encoder.blocks.1.msa.Dropout_dro...  [1, 12, 197, 197]
# 21_transformer_encoder.blocks.1.msa.Linear_fc_o         [1, 197, 768]
# 22_transformer_encoder.blocks.1.Dropout_dropout         [1, 197, 768]
# 23_transformer_encoder.blocks.1.LayerNorm_layer...      [1, 197, 768]
# 24_transformer_encoder.blocks.1.mlp.Linear_fc1         [1, 197, 3072]
# 25_transformer_encoder.blocks.1.mlp.GELU_activa...     [1, 197, 3072]
# 26_transformer_encoder.blocks.1.mlp.Dropout_dro...     [1, 197, 3072]
# 27_transformer_encoder.blocks.1.mlp.Linear_fc2          [1, 197, 768]
# 28_transformer_encoder.blocks.1.mlp.Dropout_dro...      [1, 197, 768]
# 29_transformer_encoder.blocks.1.Dropout_dropout         [1, 197, 768]
# 30_transformer_encoder.blocks.2.LayerNorm_layer...      [1, 197, 768]
# 31_transformer_encoder.blocks.2.msa.Linear_fc_q         [1, 197, 768]
# 32_transformer_encoder.blocks.2.msa.Linear_fc_k         [1, 197, 768]
# 33_transformer_encoder.blocks.2.msa.Linear_fc_v         [1, 197, 768]
# 34_transformer_encoder.blocks.2.msa.Dropout_dro...  [1, 12, 197, 197]
# 35_transformer_encoder.blocks.2.msa.Linear_fc_o         [1, 197, 768]
# 36_transformer_encoder.blocks.2.Dropout_dropout         [1, 197, 768]
# 37_transformer_encoder.blocks.2.LayerNorm_layer...      [1, 197, 768]
# 38_transformer_encoder.blocks.2.mlp.Linear_fc1         [1, 197, 3072]
# 39_transformer_encoder.blocks.2.mlp.GELU_activa...     [1, 197, 3072]
# 40_transformer_encoder.blocks.2.mlp.Dropout_dro...     [1, 197, 3072]
# 41_transformer_encoder.blocks.2.mlp.Linear_fc2          [1, 197, 768]
# 42_transformer_encoder.blocks.2.mlp.Dropout_dro...      [1, 197, 768]
# 43_transformer_encoder.blocks.2.Dropout_dropout         [1, 197, 768]
# 44_transformer_encoder.blocks.3.LayerNorm_layer...      [1, 197, 768]
# 45_transformer_encoder.blocks.3.msa.Linear_fc_q         [1, 197, 768]
# 46_transformer_encoder.blocks.3.msa.Linear_fc_k         [1, 197, 768]
# 47_transformer_encoder.blocks.3.msa.Linear_fc_v         [1, 197, 768]
# 48_transformer_encoder.blocks.3.msa.Dropout_dro...  [1, 12, 197, 197]
# 49_transformer_encoder.blocks.3.msa.Linear_fc_o         [1, 197, 768]
# 50_transformer_encoder.blocks.3.Dropout_dropout         [1, 197, 768]
# 51_transformer_encoder.blocks.3.LayerNorm_layer...      [1, 197, 768]
# 52_transformer_encoder.blocks.3.mlp.Linear_fc1         [1, 197, 3072]
# 53_transformer_encoder.blocks.3.mlp.GELU_activa...     [1, 197, 3072]
# 54_transformer_encoder.blocks.3.mlp.Dropout_dro...     [1, 197, 3072]
# 55_transformer_encoder.blocks.3.mlp.Linear_fc2          [1, 197, 768]
# 56_transformer_encoder.blocks.3.mlp.Dropout_dro...      [1, 197, 768]
# 57_transformer_encoder.blocks.3.Dropout_dropout         [1, 197, 768]
# 58_transformer_encoder.blocks.4.LayerNorm_layer...      [1, 197, 768]
# 59_transformer_encoder.blocks.4.msa.Linear_fc_q         [1, 197, 768]
# 60_transformer_encoder.blocks.4.msa.Linear_fc_k         [1, 197, 768]
# 61_transformer_encoder.blocks.4.msa.Linear_fc_v         [1, 197, 768]
# 62_transformer_encoder.blocks.4.msa.Dropout_dro...  [1, 12, 197, 197]
# 63_transformer_encoder.blocks.4.msa.Linear_fc_o         [1, 197, 768]
# 64_transformer_encoder.blocks.4.Dropout_dropout         [1, 197, 768]
# 65_transformer_encoder.blocks.4.LayerNorm_layer...      [1, 197, 768]
# 66_transformer_encoder.blocks.4.mlp.Linear_fc1         [1, 197, 3072]
# 67_transformer_encoder.blocks.4.mlp.GELU_activa...     [1, 197, 3072]
# 68_transformer_encoder.blocks.4.mlp.Dropout_dro...     [1, 197, 3072]
# 69_transformer_encoder.blocks.4.mlp.Linear_fc2          [1, 197, 768]
# 70_transformer_encoder.blocks.4.mlp.Dropout_dro...      [1, 197, 768]
# 71_transformer_encoder.blocks.4.Dropout_dropout         [1, 197, 768]
# 72_transformer_encoder.blocks.5.LayerNorm_layer...      [1, 197, 768]
# 73_transformer_encoder.blocks.5.msa.Linear_fc_q         [1, 197, 768]
# 74_transformer_encoder.blocks.5.msa.Linear_fc_k         [1, 197, 768]
# 75_transformer_encoder.blocks.5.msa.Linear_fc_v         [1, 197, 768]
# 76_transformer_encoder.blocks.5.msa.Dropout_dro...  [1, 12, 197, 197]
# 77_transformer_encoder.blocks.5.msa.Linear_fc_o         [1, 197, 768]
# 78_transformer_encoder.blocks.5.Dropout_dropout         [1, 197, 768]
# 79_transformer_encoder.blocks.5.LayerNorm_layer...      [1, 197, 768]
# 80_transformer_encoder.blocks.5.mlp.Linear_fc1         [1, 197, 3072]
# 81_transformer_encoder.blocks.5.mlp.GELU_activa...     [1, 197, 3072]
# 82_transformer_encoder.blocks.5.mlp.Dropout_dro...     [1, 197, 3072]
# 83_transformer_encoder.blocks.5.mlp.Linear_fc2          [1, 197, 768]
# 84_transformer_encoder.blocks.5.mlp.Dropout_dro...      [1, 197, 768]
# 85_transformer_encoder.blocks.5.Dropout_dropout         [1, 197, 768]
# 86_transformer_encoder.blocks.6.LayerNorm_layer...      [1, 197, 768]
# 87_transformer_encoder.blocks.6.msa.Linear_fc_q         [1, 197, 768]
# 88_transformer_encoder.blocks.6.msa.Linear_fc_k         [1, 197, 768]
# 89_transformer_encoder.blocks.6.msa.Linear_fc_v         [1, 197, 768]
# 90_transformer_encoder.blocks.6.msa.Dropout_dro...  [1, 12, 197, 197]
# 91_transformer_encoder.blocks.6.msa.Linear_fc_o         [1, 197, 768]
# 92_transformer_encoder.blocks.6.Dropout_dropout         [1, 197, 768]
# 93_transformer_encoder.blocks.6.LayerNorm_layer...      [1, 197, 768]
# 94_transformer_encoder.blocks.6.mlp.Linear_fc1         [1, 197, 3072]
# 95_transformer_encoder.blocks.6.mlp.GELU_activa...     [1, 197, 3072]
# 96_transformer_encoder.blocks.6.mlp.Dropout_dro...     [1, 197, 3072]
# 97_transformer_encoder.blocks.6.mlp.Linear_fc2          [1, 197, 768]
# 98_transformer_encoder.blocks.6.mlp.Dropout_dro...      [1, 197, 768]
# 99_transformer_encoder.blocks.6.Dropout_dropout         [1, 197, 768]
# 100_transformer_encoder.blocks.7.LayerNorm_laye...      [1, 197, 768]
# 101_transformer_encoder.blocks.7.msa.Linear_fc_q        [1, 197, 768]
# 102_transformer_encoder.blocks.7.msa.Linear_fc_k        [1, 197, 768]
# 103_transformer_encoder.blocks.7.msa.Linear_fc_v        [1, 197, 768]
# 104_transformer_encoder.blocks.7.msa.Dropout_dr...  [1, 12, 197, 197]
# 105_transformer_encoder.blocks.7.msa.Linear_fc_o        [1, 197, 768]
# 106_transformer_encoder.blocks.7.Dropout_dropout        [1, 197, 768]
# 107_transformer_encoder.blocks.7.LayerNorm_laye...      [1, 197, 768]
# 108_transformer_encoder.blocks.7.mlp.Linear_fc1        [1, 197, 3072]
# 109_transformer_encoder.blocks.7.mlp.GELU_activ...     [1, 197, 3072]
# 110_transformer_encoder.blocks.7.mlp.Dropout_dr...     [1, 197, 3072]
# 111_transformer_encoder.blocks.7.mlp.Linear_fc2         [1, 197, 768]
# 112_transformer_encoder.blocks.7.mlp.Dropout_dr...      [1, 197, 768]
# 113_transformer_encoder.blocks.7.Dropout_dropout        [1, 197, 768]
# 114_transformer_encoder.blocks.8.LayerNorm_laye...      [1, 197, 768]
# 115_transformer_encoder.blocks.8.msa.Linear_fc_q        [1, 197, 768]
# 116_transformer_encoder.blocks.8.msa.Linear_fc_k        [1, 197, 768]
# 117_transformer_encoder.blocks.8.msa.Linear_fc_v        [1, 197, 768]
# 118_transformer_encoder.blocks.8.msa.Dropout_dr...  [1, 12, 197, 197]
# 119_transformer_encoder.blocks.8.msa.Linear_fc_o        [1, 197, 768]
# 120_transformer_encoder.blocks.8.Dropout_dropout        [1, 197, 768]
# 121_transformer_encoder.blocks.8.LayerNorm_laye...      [1, 197, 768]
# 122_transformer_encoder.blocks.8.mlp.Linear_fc1        [1, 197, 3072]
# 123_transformer_encoder.blocks.8.mlp.GELU_activ...     [1, 197, 3072]
# 124_transformer_encoder.blocks.8.mlp.Dropout_dr...     [1, 197, 3072]
# 125_transformer_encoder.blocks.8.mlp.Linear_fc2         [1, 197, 768]
# 126_transformer_encoder.blocks.8.mlp.Dropout_dr...      [1, 197, 768]
# 127_transformer_encoder.blocks.8.Dropout_dropout        [1, 197, 768]
# 128_transformer_encoder.blocks.9.LayerNorm_laye...      [1, 197, 768]
# 129_transformer_encoder.blocks.9.msa.Linear_fc_q        [1, 197, 768]
# 130_transformer_encoder.blocks.9.msa.Linear_fc_k        [1, 197, 768]
# 131_transformer_encoder.blocks.9.msa.Linear_fc_v        [1, 197, 768]
# 132_transformer_encoder.blocks.9.msa.Dropout_dr...  [1, 12, 197, 197]
# 133_transformer_encoder.blocks.9.msa.Linear_fc_o        [1, 197, 768]
# 134_transformer_encoder.blocks.9.Dropout_dropout        [1, 197, 768]
# 135_transformer_encoder.blocks.9.LayerNorm_laye...      [1, 197, 768]
# 136_transformer_encoder.blocks.9.mlp.Linear_fc1        [1, 197, 3072]
# 137_transformer_encoder.blocks.9.mlp.GELU_activ...     [1, 197, 3072]
# 138_transformer_encoder.blocks.9.mlp.Dropout_dr...     [1, 197, 3072]
# 139_transformer_encoder.blocks.9.mlp.Linear_fc2         [1, 197, 768]
# 140_transformer_encoder.blocks.9.mlp.Dropout_dr...      [1, 197, 768]
# 141_transformer_encoder.blocks.9.Dropout_dropout        [1, 197, 768]
# 142_transformer_encoder.blocks.10.LayerNorm_lay...      [1, 197, 768]
# 143_transformer_encoder.blocks.10.msa.Linear_fc_q       [1, 197, 768]
# 144_transformer_encoder.blocks.10.msa.Linear_fc_k       [1, 197, 768]
# 145_transformer_encoder.blocks.10.msa.Linear_fc_v       [1, 197, 768]
# 146_transformer_encoder.blocks.10.msa.Dropout_d...  [1, 12, 197, 197]
# 147_transformer_encoder.blocks.10.msa.Linear_fc_o       [1, 197, 768]
# 148_transformer_encoder.blocks.10.Dropout_dropout       [1, 197, 768]
# 149_transformer_encoder.blocks.10.LayerNorm_lay...      [1, 197, 768]
# 150_transformer_encoder.blocks.10.mlp.Linear_fc1       [1, 197, 3072]
# 151_transformer_encoder.blocks.10.mlp.GELU_acti...     [1, 197, 3072]
# 152_transformer_encoder.blocks.10.mlp.Dropout_d...     [1, 197, 3072]
# 153_transformer_encoder.blocks.10.mlp.Linear_fc2        [1, 197, 768]
# 154_transformer_encoder.blocks.10.mlp.Dropout_d...      [1, 197, 768]
# 155_transformer_encoder.blocks.10.Dropout_dropout       [1, 197, 768]
# 156_transformer_encoder.blocks.11.LayerNorm_lay...      [1, 197, 768]
# 157_transformer_encoder.blocks.11.msa.Linear_fc_q       [1, 197, 768]
# 158_transformer_encoder.blocks.11.msa.Linear_fc_k       [1, 197, 768]
# 159_transformer_encoder.blocks.11.msa.Linear_fc_v       [1, 197, 768]
# 160_transformer_encoder.blocks.11.msa.Dropout_d...  [1, 12, 197, 197]
# 161_transformer_encoder.blocks.11.msa.Linear_fc_o       [1, 197, 768]
# 162_transformer_encoder.blocks.11.Dropout_dropout       [1, 197, 768]
# 163_transformer_encoder.blocks.11.LayerNorm_lay...      [1, 197, 768]
# 164_transformer_encoder.blocks.11.mlp.Linear_fc1       [1, 197, 3072]
# 165_transformer_encoder.blocks.11.mlp.GELU_acti...     [1, 197, 3072]
# 166_transformer_encoder.blocks.11.mlp.Dropout_d...     [1, 197, 3072]
# 167_transformer_encoder.blocks.11.mlp.Linear_fc2        [1, 197, 768]
# 168_transformer_encoder.blocks.11.mlp.Dropout_d...      [1, 197, 768]
# 169_transformer_encoder.blocks.11.Dropout_dropout       [1, 197, 768]
# 170_mlp_head                                                  [1, 10]
#
#                                                        Params  Mult-Adds
# Layer
# 0_to_patch                                                  -          -
# 1_linear_projection                                  590.592k   589.824k
# 2_transformer_encoder.blocks.0.LayerNorm_layer_...     1.536k      768.0
# 3_transformer_encoder.blocks.0.msa.Linear_fc_q       590.592k   589.824k
# 4_transformer_encoder.blocks.0.msa.Linear_fc_k       590.592k   589.824k
# 5_transformer_encoder.blocks.0.msa.Linear_fc_v       590.592k   589.824k
# 6_transformer_encoder.blocks.0.msa.Dropout_dropout          -          -
# 7_transformer_encoder.blocks.0.msa.Linear_fc_o       590.592k   589.824k
# 8_transformer_encoder.blocks.0.Dropout_dropout              -          -
# 9_transformer_encoder.blocks.0.LayerNorm_layer_...     1.536k      768.0
# 10_transformer_encoder.blocks.0.mlp.Linear_fc1      2.362368M  2.359296M
# 11_transformer_encoder.blocks.0.mlp.GELU_activa...          -          -
# 12_transformer_encoder.blocks.0.mlp.Dropout_dro...          -          -
# 13_transformer_encoder.blocks.0.mlp.Linear_fc2      2.360064M  2.359296M
# 14_transformer_encoder.blocks.0.mlp.Dropout_dro...          -          -
# 15_transformer_encoder.blocks.0.Dropout_dropout             -          -
# 16_transformer_encoder.blocks.1.LayerNorm_layer...     1.536k      768.0
# 17_transformer_encoder.blocks.1.msa.Linear_fc_q      590.592k   589.824k
# 18_transformer_encoder.blocks.1.msa.Linear_fc_k      590.592k   589.824k
# 19_transformer_encoder.blocks.1.msa.Linear_fc_v      590.592k   589.824k
# 20_transformer_encoder.blocks.1.msa.Dropout_dro...          -          -
# 21_transformer_encoder.blocks.1.msa.Linear_fc_o      590.592k   589.824k
# 22_transformer_encoder.blocks.1.Dropout_dropout             -          -
# 23_transformer_encoder.blocks.1.LayerNorm_layer...     1.536k      768.0
# 24_transformer_encoder.blocks.1.mlp.Linear_fc1      2.362368M  2.359296M
# 25_transformer_encoder.blocks.1.mlp.GELU_activa...          -          -
# 26_transformer_encoder.blocks.1.mlp.Dropout_dro...          -          -
# 27_transformer_encoder.blocks.1.mlp.Linear_fc2      2.360064M  2.359296M
# 28_transformer_encoder.blocks.1.mlp.Dropout_dro...          -          -
# 29_transformer_encoder.blocks.1.Dropout_dropout             -          -
# 30_transformer_encoder.blocks.2.LayerNorm_layer...     1.536k      768.0
# 31_transformer_encoder.blocks.2.msa.Linear_fc_q      590.592k   589.824k
# 32_transformer_encoder.blocks.2.msa.Linear_fc_k      590.592k   589.824k
# 33_transformer_encoder.blocks.2.msa.Linear_fc_v      590.592k   589.824k
# 34_transformer_encoder.blocks.2.msa.Dropout_dro...          -          -
# 35_transformer_encoder.blocks.2.msa.Linear_fc_o      590.592k   589.824k
# 36_transformer_encoder.blocks.2.Dropout_dropout             -          -
# 37_transformer_encoder.blocks.2.LayerNorm_layer...     1.536k      768.0
# 38_transformer_encoder.blocks.2.mlp.Linear_fc1      2.362368M  2.359296M
# 39_transformer_encoder.blocks.2.mlp.GELU_activa...          -          -
# 40_transformer_encoder.blocks.2.mlp.Dropout_dro...          -          -
# 41_transformer_encoder.blocks.2.mlp.Linear_fc2      2.360064M  2.359296M
# 42_transformer_encoder.blocks.2.mlp.Dropout_dro...          -          -
# 43_transformer_encoder.blocks.2.Dropout_dropout             -          -
# 44_transformer_encoder.blocks.3.LayerNorm_layer...     1.536k      768.0
# 45_transformer_encoder.blocks.3.msa.Linear_fc_q      590.592k   589.824k
# 46_transformer_encoder.blocks.3.msa.Linear_fc_k      590.592k   589.824k
# 47_transformer_encoder.blocks.3.msa.Linear_fc_v      590.592k   589.824k
# 48_transformer_encoder.blocks.3.msa.Dropout_dro...          -          -
# 49_transformer_encoder.blocks.3.msa.Linear_fc_o      590.592k   589.824k
# 50_transformer_encoder.blocks.3.Dropout_dropout             -          -
# 51_transformer_encoder.blocks.3.LayerNorm_layer...     1.536k      768.0
# 52_transformer_encoder.blocks.3.mlp.Linear_fc1      2.362368M  2.359296M
# 53_transformer_encoder.blocks.3.mlp.GELU_activa...          -          -
# 54_transformer_encoder.blocks.3.mlp.Dropout_dro...          -          -
# 55_transformer_encoder.blocks.3.mlp.Linear_fc2      2.360064M  2.359296M
# 56_transformer_encoder.blocks.3.mlp.Dropout_dro...          -          -
# 57_transformer_encoder.blocks.3.Dropout_dropout             -          -
# 58_transformer_encoder.blocks.4.LayerNorm_layer...     1.536k      768.0
# 59_transformer_encoder.blocks.4.msa.Linear_fc_q      590.592k   589.824k
# 60_transformer_encoder.blocks.4.msa.Linear_fc_k      590.592k   589.824k
# 61_transformer_encoder.blocks.4.msa.Linear_fc_v      590.592k   589.824k
# 62_transformer_encoder.blocks.4.msa.Dropout_dro...          -          -
# 63_transformer_encoder.blocks.4.msa.Linear_fc_o      590.592k   589.824k
# 64_transformer_encoder.blocks.4.Dropout_dropout             -          -
# 65_transformer_encoder.blocks.4.LayerNorm_layer...     1.536k      768.0
# 66_transformer_encoder.blocks.4.mlp.Linear_fc1      2.362368M  2.359296M
# 67_transformer_encoder.blocks.4.mlp.GELU_activa...          -          -
# 68_transformer_encoder.blocks.4.mlp.Dropout_dro...          -          -
# 69_transformer_encoder.blocks.4.mlp.Linear_fc2      2.360064M  2.359296M
# 70_transformer_encoder.blocks.4.mlp.Dropout_dro...          -          -
# 71_transformer_encoder.blocks.4.Dropout_dropout             -          -
# 72_transformer_encoder.blocks.5.LayerNorm_layer...     1.536k      768.0
# 73_transformer_encoder.blocks.5.msa.Linear_fc_q      590.592k   589.824k
# 74_transformer_encoder.blocks.5.msa.Linear_fc_k      590.592k   589.824k
# 75_transformer_encoder.blocks.5.msa.Linear_fc_v      590.592k   589.824k
# 76_transformer_encoder.blocks.5.msa.Dropout_dro...          -          -
# 77_transformer_encoder.blocks.5.msa.Linear_fc_o      590.592k   589.824k
# 78_transformer_encoder.blocks.5.Dropout_dropout             -          -
# 79_transformer_encoder.blocks.5.LayerNorm_layer...     1.536k      768.0
# 80_transformer_encoder.blocks.5.mlp.Linear_fc1      2.362368M  2.359296M
# 81_transformer_encoder.blocks.5.mlp.GELU_activa...          -          -
# 82_transformer_encoder.blocks.5.mlp.Dropout_dro...          -          -
# 83_transformer_encoder.blocks.5.mlp.Linear_fc2      2.360064M  2.359296M
# 84_transformer_encoder.blocks.5.mlp.Dropout_dro...          -          -
# 85_transformer_encoder.blocks.5.Dropout_dropout             -          -
# 86_transformer_encoder.blocks.6.LayerNorm_layer...     1.536k      768.0
# 87_transformer_encoder.blocks.6.msa.Linear_fc_q      590.592k   589.824k
# 88_transformer_encoder.blocks.6.msa.Linear_fc_k      590.592k   589.824k
# 89_transformer_encoder.blocks.6.msa.Linear_fc_v      590.592k   589.824k
# 90_transformer_encoder.blocks.6.msa.Dropout_dro...          -          -
# 91_transformer_encoder.blocks.6.msa.Linear_fc_o      590.592k   589.824k
# 92_transformer_encoder.blocks.6.Dropout_dropout             -          -
# 93_transformer_encoder.blocks.6.LayerNorm_layer...     1.536k      768.0
# 94_transformer_encoder.blocks.6.mlp.Linear_fc1      2.362368M  2.359296M
# 95_transformer_encoder.blocks.6.mlp.GELU_activa...          -          -
# 96_transformer_encoder.blocks.6.mlp.Dropout_dro...          -          -
# 97_transformer_encoder.blocks.6.mlp.Linear_fc2      2.360064M  2.359296M
# 98_transformer_encoder.blocks.6.mlp.Dropout_dro...          -          -
# 99_transformer_encoder.blocks.6.Dropout_dropout             -          -
# 100_transformer_encoder.blocks.7.LayerNorm_laye...     1.536k      768.0
# 101_transformer_encoder.blocks.7.msa.Linear_fc_q     590.592k   589.824k
# 102_transformer_encoder.blocks.7.msa.Linear_fc_k     590.592k   589.824k
# 103_transformer_encoder.blocks.7.msa.Linear_fc_v     590.592k   589.824k
# 104_transformer_encoder.blocks.7.msa.Dropout_dr...          -          -
# 105_transformer_encoder.blocks.7.msa.Linear_fc_o     590.592k   589.824k
# 106_transformer_encoder.blocks.7.Dropout_dropout            -          -
# 107_transformer_encoder.blocks.7.LayerNorm_laye...     1.536k      768.0
# 108_transformer_encoder.blocks.7.mlp.Linear_fc1     2.362368M  2.359296M
# 109_transformer_encoder.blocks.7.mlp.GELU_activ...          -          -
# 110_transformer_encoder.blocks.7.mlp.Dropout_dr...          -          -
# 111_transformer_encoder.blocks.7.mlp.Linear_fc2     2.360064M  2.359296M
# 112_transformer_encoder.blocks.7.mlp.Dropout_dr...          -          -
# 113_transformer_encoder.blocks.7.Dropout_dropout            -          -
# 114_transformer_encoder.blocks.8.LayerNorm_laye...     1.536k      768.0
# 115_transformer_encoder.blocks.8.msa.Linear_fc_q     590.592k   589.824k
# 116_transformer_encoder.blocks.8.msa.Linear_fc_k     590.592k   589.824k
# 117_transformer_encoder.blocks.8.msa.Linear_fc_v     590.592k   589.824k
# 118_transformer_encoder.blocks.8.msa.Dropout_dr...          -          -
# 119_transformer_encoder.blocks.8.msa.Linear_fc_o     590.592k   589.824k
# 120_transformer_encoder.blocks.8.Dropout_dropout            -          -
# 121_transformer_encoder.blocks.8.LayerNorm_laye...     1.536k      768.0
# 122_transformer_encoder.blocks.8.mlp.Linear_fc1     2.362368M  2.359296M
# 123_transformer_encoder.blocks.8.mlp.GELU_activ...          -          -
# 124_transformer_encoder.blocks.8.mlp.Dropout_dr...          -          -
# 125_transformer_encoder.blocks.8.mlp.Linear_fc2     2.360064M  2.359296M
# 126_transformer_encoder.blocks.8.mlp.Dropout_dr...          -          -
# 127_transformer_encoder.blocks.8.Dropout_dropout            -          -
# 128_transformer_encoder.blocks.9.LayerNorm_laye...     1.536k      768.0
# 129_transformer_encoder.blocks.9.msa.Linear_fc_q     590.592k   589.824k
# 130_transformer_encoder.blocks.9.msa.Linear_fc_k     590.592k   589.824k
# 131_transformer_encoder.blocks.9.msa.Linear_fc_v     590.592k   589.824k
# 132_transformer_encoder.blocks.9.msa.Dropout_dr...          -          -
# 133_transformer_encoder.blocks.9.msa.Linear_fc_o     590.592k   589.824k
# 134_transformer_encoder.blocks.9.Dropout_dropout            -          -
# 135_transformer_encoder.blocks.9.LayerNorm_laye...     1.536k      768.0
# 136_transformer_encoder.blocks.9.mlp.Linear_fc1     2.362368M  2.359296M
# 137_transformer_encoder.blocks.9.mlp.GELU_activ...          -          -
# 138_transformer_encoder.blocks.9.mlp.Dropout_dr...          -          -
# 139_transformer_encoder.blocks.9.mlp.Linear_fc2     2.360064M  2.359296M
# 140_transformer_encoder.blocks.9.mlp.Dropout_dr...          -          -
# 141_transformer_encoder.blocks.9.Dropout_dropout            -          -
# 142_transformer_encoder.blocks.10.LayerNorm_lay...     1.536k      768.0
# 143_transformer_encoder.blocks.10.msa.Linear_fc_q    590.592k   589.824k
# 144_transformer_encoder.blocks.10.msa.Linear_fc_k    590.592k   589.824k
# 145_transformer_encoder.blocks.10.msa.Linear_fc_v    590.592k   589.824k
# 146_transformer_encoder.blocks.10.msa.Dropout_d...          -          -
# 147_transformer_encoder.blocks.10.msa.Linear_fc_o    590.592k   589.824k
# 148_transformer_encoder.blocks.10.Dropout_dropout           -          -
# 149_transformer_encoder.blocks.10.LayerNorm_lay...     1.536k      768.0
# 150_transformer_encoder.blocks.10.mlp.Linear_fc1    2.362368M  2.359296M
# 151_transformer_encoder.blocks.10.mlp.GELU_acti...          -          -
# 152_transformer_encoder.blocks.10.mlp.Dropout_d...          -          -
# 153_transformer_encoder.blocks.10.mlp.Linear_fc2    2.360064M  2.359296M
# 154_transformer_encoder.blocks.10.mlp.Dropout_d...          -          -
# 155_transformer_encoder.blocks.10.Dropout_dropout           -          -
# 156_transformer_encoder.blocks.11.LayerNorm_lay...     1.536k      768.0
# 157_transformer_encoder.blocks.11.msa.Linear_fc_q    590.592k   589.824k
# 158_transformer_encoder.blocks.11.msa.Linear_fc_k    590.592k   589.824k
# 159_transformer_encoder.blocks.11.msa.Linear_fc_v    590.592k   589.824k
# 160_transformer_encoder.blocks.11.msa.Dropout_d...          -          -
# 161_transformer_encoder.blocks.11.msa.Linear_fc_o    590.592k   589.824k
# 162_transformer_encoder.blocks.11.Dropout_dropout           -          -
# 163_transformer_encoder.blocks.11.LayerNorm_lay...     1.536k      768.0
# 164_transformer_encoder.blocks.11.mlp.Linear_fc1    2.362368M  2.359296M
# 165_transformer_encoder.blocks.11.mlp.GELU_acti...          -          -
# 166_transformer_encoder.blocks.11.mlp.Dropout_d...          -          -
# 167_transformer_encoder.blocks.11.mlp.Linear_fc2    2.360064M  2.359296M
# 168_transformer_encoder.blocks.11.mlp.Dropout_d...          -          -
# 169_transformer_encoder.blocks.11.Dropout_dropout           -          -
# 170_mlp_head                                            7.69k      7.68k
# -------------------------------------------------------------------------------------------------------------
#                           Totals
# Total params          85.652746M
# Trainable params      85.652746M
# Non-trainable params         0.0
# Mult-Adds             85.550592M
# =============================================================================================================

# %%
import random

plot_attention_map(data[random.randint(0, 10000)], model, 224, 'cpu')

# %%
pos_embeddings = model.pos_embedding.squeeze()[1:, :]
plot_pos_emb_similarity(pos_embeddings, 7, 7)

# %%
import logging
logger = logging.getLogger()
logger.setLevel(100)

embed_filters = model.linear_projection.weight
plot_rgb_filters(embed_filters, 3, 16)

# %%
from modules import TransformerEncoder

all_block = []
for model_child in list(model.children()):
    if type(model_child) != torch.nn.modules.container.ModuleList:
        if isinstance(model_child, TransformerEncoder):
            for i in range(12):
                all_block.append(model_child.blocks[i])
        else:
            all_block.append(model_child)

# %%
all_block[2]
# Out:
# TransformerEncoderBlock(
#   (msa): MSA(
#     (fc_q): Linear(in_features=768, out_features=768, bias=True)
#     (fc_k): Linear(in_features=768, out_features=768, bias=True)
#     (fc_v): Linear(in_features=768, out_features=768, bias=True)
#     (fc_o): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (mlp): MLP(
#     (fc1): Linear(in_features=768, out_features=3072, bias=True)
#     (fc2): Linear(in_features=3072, out_features=768, bias=True)
#     (activation): GELU()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
# )
